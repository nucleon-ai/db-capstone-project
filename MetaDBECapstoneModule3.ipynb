# %% [markdown]
# # Meta Database Engineer Capstone Project

# %% [markdown]
# ## First Exercise
# ### Task 1

# %%
# !python --version
# Out:
# Python 3.11.2

# %% [markdown]
# ### Task 2

# %% [markdown]
# ##### Following commands ran to configure and create this jupyter notebook
# - python -m pip install jupyter
# - jupyter notebook

# %% [markdown]
# ### Task 3
# #### Step 1

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp311-cp311-win_amd64.whl (16.5 MB)
#      ---------------------------------------- 16.5/16.5 MB 2.5 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Step 2

# %%
import mysql.connector as connector

# %% [markdown]
# #### Step 3

# %%
connection = connector.connect(user = "root", password = "")

# %%
connection.is_connected()
# Out:
# True

# %% [markdown]
# ## Second Exercise
# ### Task 1

# %%
connection = connector.connect(user = "root", password = "", db = "littlelemondb")

# %% [markdown]
# ### Task 2

# %%
with connection.cursor() as cursor:
    show_tables_query = "SHOW tables" 
    cursor.execute(show_tables_query)
    results = cursor.fetchall()
    print(results)
# Out:
# [('bookings',), ('customers',), ('menuitems',), ('menus',), ('orders',), ('ordersview',)]

# %% [markdown]
# ### Task 3

# %%
query_stmt = """
    SELECT customers.FullName, customers.ContactNumber, orders.TotalCost
    FROM customers
    LEFT JOIN orders ON orders.CustomerID = customers.CustomerID
    WHERE orders.TotalCost > 60;
"""
with connection.cursor() as cursor:
    cursor.execute(query_stmt)
    results = cursor.fetchall()
    print(results)
# Out:
# [('Anya Davis', '227680402', Decimal('111.90')), ('Anya Davis', '227680402', Decimal('133.24')), ('Anya Davis', '227680402', Decimal('83.29')), ('Ryan Ward', '165258086', Decimal('161.70')), ('Ryan Ward', '165258086', Decimal('217.00')), ('Ryan Ward', '165258086', Decimal('162.83')), ('Evan Singh', '1930086875', Decimal('199.40')), ('Evan Singh', '1930086875', Decimal('220.45')), ('Evan Singh', '1930086875', Decimal('103.88')), ('Evan Singh', '1930086875', Decimal('204.87')), ('Iris Green', '268310679', Decimal('185.92')), ('Iris Green', '268310679', Decimal('149.93')), ('Iris Green', '268310679', Decimal('210.82')), ('Tara Khan', '8348136760', Decimal('85.36')), ('Tara Khan', '8348136760', Decimal('157.46')), ('Tara Khan', '8348136760', Decimal('153.93')), ('Anya Lopez', '5242962370', Decimal('102.95')), ('Anya Lopez', '5242962370', Decimal('148.68')), ('Anya Lopez', '5242962370', Decimal('61.92')), ('Anya Lopez', '5242962370', Decimal('175.65')), ('Seth Jones', '8409572486', Decimal('83.66')), ('Seth Jones', '8409572486', Decimal('208.79')), ('Seth Jones', '8409572486', Decimal('201.33')), ('Seth Jones', '8409572486', Decimal('153.54')), ('Zoe Singh', '1757453914', Decimal('71.48')), ('Zoe Singh', '1757453914', Decimal('94.98')), ('Zoe Singh', '1757453914', Decimal('162.77')), ('Zoe Singh', '1757453914', Decimal('161.68')), ('Hugo Jones', '8116535425', Decimal('100.24')), ('Hugo Jones', '8116535425', Decimal('199.12')), ('Hugo Jones', '8116535425', Decimal('152.78')), ('Hugo Jones', '8116535425', Decimal('142.65')), ('Ava Gray', '7652614498', Decimal('78.97')), ('Ava Gray', '7652614498', Decimal('64.26')), ('Ava Gray', '7652614498', Decimal('157.13')), ('Ava Gray', '7652614498', Decimal('209.84')), ('Owen Perez', '7516851319', Decimal('142.99')), ('Owen Perez', '7516851319', Decimal('176.95')), ('Owen Perez', '7516851319', Decimal('115.81')), ('Iris Perez', '9541398225', Decimal('195.36')), ('Iris Perez', '9541398225', Decimal('98.87')), ('Iris Perez', '9541398225', Decimal('115.80')), ('Noah Brown', '7895169156', Decimal('157.44')), ('Noah Brown', '7895169156', Decimal('101.24')), ('Noah Brown', '7895169156', Decimal('207.87')), ('Noah Brown', '7895169156', Decimal('176.88')), ('Ivy Adams', '5723964512', Decimal('201.77')), ('Ivy Adams', '5723964512', Decimal('195.59')), ('Ivy Adams', '5723964512', Decimal('199.30')), ('Ivy Adams', '5723964512', Decimal('74.91')), ('Evan Smith', '5220629802', Decimal('192.18')), ('Evan Smith', '5220629802', Decimal('203.63')), ('Evan Smith', '5220629802', Decimal('144.52')), ('Evan Smith', '5220629802', Decimal('147.13')), ('Omar Diaz', '2195478104', Decimal('63.12')), ('Omar Diaz', '2195478104', Decimal('102.13')), ('Omar Diaz', '2195478104', Decimal('117.36')), ('Omar Diaz', '2195478104', Decimal('182.73')), ('Milo Baker', '4769043821', Decimal('144.57')), ('Milo Baker', '4769043821', Decimal('161.19')), ('Milo Baker', '4769043821', Decimal('214.40')), ('Milo Baker', '4769043821', Decimal('206.80')), ('Leah Clark', '4229485098', Decimal('62.27')), ('Leah Clark', '4229485098', Decimal('138.56')), ('Leah Clark', '4229485098', Decimal('185.57')), ('Noah Adams', '7244891039', Decimal('124.87')), ('Noah Adams', '7244891039', Decimal('77.39')), ('Noah Adams', '7244891039', Decimal('77.73')), ('Noah Adams', '7244891039', Decimal('107.68')), ('Kira Cruz', '2677641207', Decimal('66.55')), ('Kira Cruz', '2677641207', Decimal('83.47')), ('Kira Cruz', '2677641207', Decimal('181.84')), ('Kira Cruz', '2677641207', Decimal('140.64')), ('Liam Wood', '3049505800', Decimal('169.40')), ('Liam Wood', '3049505800', Decimal('98.46')), ('Liam Wood', '3049505800', Decimal('189.60')), ('Tara Khan', '4955006532', Decimal('102.84')), ('Tara Khan', '4955006532', Decimal('180.88')), ('Tara Khan', '4955006532', Decimal('197.98')), ('Tara Khan', '4955006532', Decimal('131.43')), ('Omar Bell', '3216499065', Decimal('145.49')), ('Omar Bell', '3216499065', Decimal('77.12')), ('Omar Bell', '3216499065', Decimal('86.93')),  ...
